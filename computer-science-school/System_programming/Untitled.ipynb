# %% [markdown]
#  시스템 프로그래밍 오리엔테이션 (19:39)
#
#  2강 리눅스 특징과 장점 (19:09)
#
#  3강 리눅스 역사와 운영체제 기술 (32:46)
#
# Start  4강 클라우드 컴퓨팅과 리눅스 설치 (AWS 회원가입) (23:20)
#
# Start  5강 클라우드 컴퓨팅과 리눅스 설치 (리눅스 서버 생성) (24:29)
#
# Start  6강 클라우드 컴퓨팅과 리눅스 설치 (리눅스 서버 접속) (18:47)
#
# Start  7강 가상 소프트웨어와 리눅스 설치 (참고 강의) (22:59)
#
# Start  8강 시스템 프로그래밍 시작 - 기본 구성 알아두기 (26:11)
#
# Start  9강 쉘 기본 사용법 - 다중 사용자 지원 (24:27)
#
# Start  10강 쉘 기본 사용법 - 파일 및 권한 관리1 (24:46)
#
# Start  11강 쉘 기본 사용법 - 파일 및 권한관리2 (24:38)
#
# Start  12강 쉘 기본 사용법 - 리다이렉션과 파이프 (35:42)
#
# Start  13강 foreground와 background 프로세스 (24:52)
#
# Start  14강 프로세스 관리 및 제어 (28:53)
#
# Start  15강 리눅스 파일 시스템 (26:20)
#
# Start  16강 리눅스 파일 시스템 탐색 (14:51)
#
# Start  17강 파일 관련 쉘 명령어 - 하드 링크 (23:39)
#
# Start  18강 파일 관련 쉘 명령어 - 소프트 링크 및 특수 파일 (18:15)
#
# Start  19강 시스템 프로그래밍 핵심 기술 - 시스템콜과 API (19:35)
#
# Start  20강 시스템 프로그래밍 핵심 기술 - ABI와 표준 (22:10)
#
# Start  21강 프로세스 관리 - 프로세스 ID (18:57)
#
# Start  22강 프로세스 관리 - 프로세스 ID 시스템콜 (12:14)
#
# Start  23강 프로세스 관리 - 프로세스 생성(fork) (21:55)
#
# Start  24강 프로세스 관리 - 프로세스 생성(exec) (27:10)
#
# Start  25강 프로세스 관리 - 프로세스 생성(wait)과 나만의 쉘만들기 (25:43)
#
# Start  26강 프로세스 관리 - 프로세스 생성 (copy on write) (18:31)
#
# Start  27강 프로세스 관리 - 프로세스 종료 (exit) (23:23)
#
# Start  28강 프로세스 관리 - 프로세스 생성과 종료 총정리 및 wait 시스템콜 상세 (24:58)
#
# Start  29강 프로세스 스케쥴링 관련(참고) (14:08)
#
# Start  30강 IPC 기법 실습1 (25:12)
#
# Start  31강 IPC 기법 실습2 (18:21)
#
# Start  32강 시그널 동작 메커니즘과 사용법 이해 (25:11)
#
# Start  33강 쉘스크립트의 이해와 변수 (25:49)
#
# Start  34강 쉘스크립트 조건문 (19:16)
#
# Start  35강 쉘스크립트 반복문과 실제 예제 (23:24)
#
# Start  36강 쉘스크립트 현업 예제 및 정리 (20:32)
#
# Start  37강 스레드(Pthread) 기본 (23:11)
#
# Start  38강 스레드(Pthread) 기본과 동기화 (23:27)
#
# Start  39강 메모리와 mmap (23:53)
#
# Start  40강 mmap 예제 및 활용 (17:38)
#
# Start  41강 파일 시스템 관련 시스템콜 이해 (25:50)
#
# Start  최종 업로드 완료
