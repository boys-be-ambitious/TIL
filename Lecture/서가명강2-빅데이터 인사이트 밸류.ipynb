# %% [markdown]
# # [Bigdata Insight Value]
# #### - Date :  2018/11/15
#
# ## Index
# ### 1.  New Service
# ### 2. Product, Service
# ### 3.
# ### 4. Marketing
# ### 5. Risk Management
# ### 6. Finance
#
# # 1. New 서비스
# ## 1.1. 타인의 추천
# - Hotels.com : 숙박 예약 서비스
# - Foursquare : 식당 추천 서비스
# - Amazon : 제품 평점
# - Naver Movie : 영화평
#
# ## 1.2. 부동산 매매/임대 플랫폼
# - Redfin : 미국의 혁신적인 부동산 중개 플랫폼
#
# ## 1.3. 이동 방법의 진화
# - 차량 주차 요금 : 앱으로 계산
# - Uber : 사람들은 언제 어디서 uber를 부르는가(수요 파악 후 기사에 정보를 줌)?
#     - 파괴적 혁신 : 기존의 질서를 뒤 흔든다. -> 전세계에서 우버를 안 쓰는 유이한 나라
#     - 세상의 발전과 동떨어져 살게 된다.
# - Self-Driving Car
#
# # 2. 상품 서비스 기획
# ## 2.1. 가전제품
# ### 2.1.1. 기술 중심 기획
# - 개발한 "음성인식" 누구에게?
#     - 기술 -> 어떤 소비자?
#
# ### 2.1.2. 사용자 중심 기획
# - 운전하면서 전화하려면?
#     - 소비자 -> 어떤 제품?
#     - 소비자의 니즈를 어떻게 해결할까? -> '음성 인식'
#
# ### 외부 Voice of Customer (소비자의 목소리)
# - (기존) Market Research
# - (요즘) Social Network
#     - 콜센터에 들어온 경우는 극단적인 케이스가 많다.
#     - 사람들의 일상적인 이야기를 들을 방법이 없다.
#     - 그렇기에 VOC 분석
#
# ### Smart Home Appliances
# - 소비자의 말이 데이터
#     - 로봇 청소기
#     - 스마트 에어컨
#     - 오븐
#         - 1단계 : 오븐 연관 검색어
#             - 부정 : 집, 귀찮음, 실패, 엄마
#             - 긍정 : 마트, 맛, 정성, 간식, 아이
#         - 2단계 :
#         - 3단계 : 키워드 + 키워드 조합
#
#         - 인터넷 레시피를 따라해도 실패한다? -> 엔지니어한테 물어봄 -> 브랜드 마다 세팅이 달라서 똑같은 효과를 내려면 예열 시간과 온도가 다 다르다. -> 맞을 리가 없다. -> 이런 게 Insight -> 인사이트를 기반으로 어떤 action을 취하면 될까?
#         - 시나리오 (대안) : 기계 맞춤형 레시피
#         - 이 시나리오를 받아들여서 실행하기까지 4년이 걸렸음
#
#     - 냉장고
#     - 세탁기
#
# ## 2.2. 에어컨 서비스
# ### 2.2.1. 제품의 서비스화 (Servitization)
# - 소비자의 관시은 제품 아닌 서비스
#     - 실내기/실외기 vs 온도 조절
#     - 차량 vs 이동
#
# - 장기적 고객 관리 및 서비스
#     - GE : 비행기 엔진, 엔진 관리 서비스
#     - DAIKIN : 에어컨(세계 최고 기술력, 시스템 에어컨을 처음 만든 회사, 동남아 백화점은 거의 다이킨 사), 1년 내내 온도 22~25도 유지 및 적정 전기료 산출 서비스 제공
#
# ### 2.2.2. 시스템 에어컨 실내기
# - 데이터
#     - On, Off times
#     - 설정 및 실제 온도
#
# - 에어컨 소비 전력 관리
#     - 빌딩 관리 주요 문제
#
#     - 부경대 전기 사용량
#         - 일과 시간에 쓰는 전기량이 압도적으로 많음(당연)
#
# # 3. 설계, 제조, 생산
# ## 3.1. 제품 설계
# ### 설계검증시스템
# - 인사이트 시각화가 인상적이었음
#
# ## 3.2. 물류의 이해
# ### 선박 조립
# ### 블록 이동 패턴 이해
# - 블록 이동은 언제 어떻게??
# - 생산 납기에 영향을 주는 병목 프로세스는?
#
# - 블록이 어떻게 움직이고 있나? (Mosaic Plot)
#     - 적치장(대기장)에서 많은 시간을 보냄
#     - 비효율적이고 위험하다(납기일을 못 맞출 가능성이 높다).
#     - 경종을 보냄
#
#
# ## 3.3. 품질 예측
# ### 3.3.1. 와인
# - 보르도 와인
#     - 와인이 아닌 상태에서 품질을 추정(만들고 6~18개월 발효 후에 출시, 만든지 6개월 만에 추정)
#
# - 와인 품질 데이터 공식
#     - 품질 = 12.145 + 0.00117 * 전년도 겨울 강수량 + 0.06140 * 당해년도 평균기옥 - 0.00386 * 수확기 강수량 +- @
#     - 온도, 햇빛, 강수량
#         - 겨울에 눈이 많이 오고, 평균 기온이 높고, 강수량이 적을수록 와인의 품질이 좋다(2000년에 공식을 발표)
#         - 겨울에 춥고, 여름에 덥고, 비가 많이 오지 않아야...
#
#     - 인간의 언어는 되게 애매모호하다. 숫자는 정확하다.
#         - Why? -> 와인의 금융 상품화
#         - 와인은 선물거래를 하기 때문에 포도주가 병에 들어가기 전에 와인을 살 권리를 가진다.
#
#
# ### 3.3.2. 반도체 제조 공정
# - 보르도 포도밭이 500개 있다고 생각하면 된다.
# - 메모리가 500단계를 거친다고 생각하면 된다.
# - 기상청처럼 데이터를 단계별로 다 측정한다.
#
# ## 3.4. 재작업 이해
# - 제조를 못했으면, 다시 하는 것
# - 검사자가 따로 있다.
#
# ### 해양구조물
# - 바다 위 공장
#     - 밑에서 원유를 뽑아서, 공장처럼 바로 정유한 다음에 배에 실음
#     - 셰일 가스 : 유가 폭락해서 망함.
#
# - 질문 : "처음부터 왜 제대로 못했는가?"
# - 어디서, 왜 발생하는가?? Pin(Pain) Point 해결
#     - 아무리 작더라도 이렇게 해서 문제를 제거하면 다시는 발생하지 않음
#     - 원인 발견
#
# ## 3.5. 품질 검사
# - AS 품질과 제조과정에서의 검사
#     - 의사결정나무를 통한 특징 파악
#
# ## 3.6. 장비 이상 작동탐지
# ### Anomaly Detection
#
#
# # 4. 마케팅, 영업
# ## 4.1. 고객 이해
# ### 신용카드 마켓 세그멘테이션
#
# 대한민국 국민을 유사도에 따라서 33개의 그룹으로 나눌 수 있다.
# 소비자는 여러 사람으로 섞여 있어서 비슷한 유형끼리 묶는다.
#
# 고객의 성격에 맞춰 Action을 취함
#
# - 각 Segment별 특징
#     - Segment 1 : Recognition
#         - 사고날 가능성이 작은 사람들에게 현금 서비스를 유도
#
#     - Segment3
#
#     - Segment4
#
#     - Segment51 : Recognition
#         - VIP는 Recognition이 중요하다.
#
#     - Segment57
#
# - TS-SP Group(타사-신판 그룹)
#     - 목적
#         - 신판 사용 유도
#         - CS 사용 촉진
#
# - CS-Only Group(현금 서비스 그룹, 월 500만원 이상 사용)
#
# #### 쪼개는 이유(Segmentation) : 그룹을 이해하고 맞춤형으로 제공
# - 그룹을 쪼개서 거기에 맞는 타겟팅을 해줘야 한다.
#
# ## 4.2. 업셀 Up Sell
# - 융단폭격이 말이 안 되는 이유 : 마케팅 비용은 한정이 되어 있기 때문에
# - 무작위 vs 플래티넘 고객처럼 사용하는 사람
# - 잘 고르기만 하면 후자의 효과가 훨씬 좋다.
#
#
# ## 4.4. 관객 수 예측
# ### 영화 관객 수 예측
# - 영화진흥위원회 : 일별 박스오피스
# - 네이버 영화 : 감독, 배우
# - Decision Tree
#
# ## 4.5. 개인화 추천
# - 아마존 : 1:1 예측 배송
# - 노래, 영화 추천 :  Spotify, Netflix
# - Harrahs : 카지노
#     - 그래프 : x축 잃은 돈, y축 돌아올 확률
#         - 매주 와서 50만원씩 평생 잃기를 원한다.
#         - 스코어를 보고 있다가 돈을 잃고 있으면 여자가 와서 서비스를 제공해서 흥분된 상태를 잠시 잘라준다. 뒤로 넘어가지 못하게...
#         - 다음주에 또 오게 만듬.
#
# - okcupid : 만남 서비스
#     - 여성은 어릴 경우 연상을 만나고 싶어하다가, 연하도 만나고 싶어한다.
#     - 남성은 꾸준히 연하를 만나고 싶어한다.
#
#     - 연락(메시지) 보낸 것
#         - 여자의 경우, 어리면 연상, 나이가 있을 경우 연하
#         - 남자의 경우, 어리거나 늙거나 연하
#
#     - 소비자에게 물어보고 나온 경우랑, 실제랑 다르다!!!!
#     - 교훈 : 언행불일치!
#     - 소비자에게 묻지 말고, 행동을 관찰해라(100배, 1000배 더 정확하다.)

# %% [markdown]
# - 영화
#     - 모델 잘 나온다. 어느 정도 수준을 보고 잘 나왔다. 그 기준은?
#     - 범주형으로 나누었다.
#     - 75~80%의 정확도
#     - 주가 예측 52% 한국에 없다.
#
# - Anomaly Detection
#
# - 카드사
#     - 세그 나누는 방법
#
# - 제조업
#     - Decision Tree는 설명력 > 정확도
#     - 예측 보다는 사후 분석
#     - AS 품질과 제조과정에서의 검사
#
# - Decision Maker에 대한 이해도를 높여서 신뢰도를 높이기
#     - 관련된, 심증이 있는 변수를 다 넣는다.
# - 그 후에 Black Box Model로 간다.
#
# - 카드, 금융 100% 내수 Business
#     - 분석을 통해서 상당히 많은 Action을 객관적으로
#     - 직관보다 성능이 향상되는 경우도 있다.
#     - 틀려도 좋다. 왜 틀렸는지 공식이 이야기 해준다. -> 분석을 할 수 있다.
#         - 사람한테 왜 틀렸는지 물어보면 변명을 한다.
#         - 사람은 어떻게 발전시킬지 난감하다.
#         - 객관적인 모델에 근거한 모델은 발전시킬 여지가 있다.
#         - 처음부터 완벽하지 않아도 계속할 이유가 된다.
